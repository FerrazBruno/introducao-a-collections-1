# %%
idade1 = 39
idade2 = 27
idade3 = 30

# %%
print(idade1)
print(idade2)
print(idade3)
# Out:
# 39
# 27
# 30

# %%
# Lista
idades = [39, 30, 27, 18]

# %%
# Tipo
type(idades)
# Out:
# list

# %%
# Endereço onde a lista está armazenado na memória
id(idades)
# Out:
# 139735766303920

# %%
# Tamanho da lista
len(idades)
# Out:
# 4

# %%
# Acessando o elemento dentro da lista através do seu indice
idades[0]
# Out:
# 39

# %%
print(idades[1])
print(idades[2])
print(idades[3])
# Out:
# 30
# 27
# 18

# %%
# Adicionando um valor ao final da lista
idades.append(15)
idades
# Out:
# [39, 30, 27, 18, 15]

# %%
idades[4]
# Out:
# 15

# %%
# Iterando sobre a lista
for idade in idades:
    print(idade)
# Out:
# 39
# 30
# 27
# 18
# 15

# %%
# Removendo um elemento da lista
idades.remove(30)
idades
# Out:
# [39, 27, 18, 15]

# %%
idades.append(15)
idades
# Out:
# [39, 27, 18, 15, 15]

# %%
# Removendo um elemento duplicado
idades.remove(15)
idades
# Out:
# [39, 27, 18, 15]

# %%
# remove() remove o primeiro elemento encontrado na lista
idades.append(27)
idades.remove(27)
idades
# Out:
# [39, 18, 15, 27]

# %%
# Removedo todos os elementos dentro de uma lista
idades.clear()
idades
# Out:
# []

# %%
# Verificando valores dentro de uma lista
15 in idades
# Out:
# False

# %%
idades = [39, 30, 27, 18]

# %%
if 18 in idades:
    idades.remove(18)

# %%
idades
# Out:
# [39, 30, 27]

# %%
idades.append(19)

# %%
# Adicionando um valor na lista em uma posição específica
idades.insert(0, 20)

# %%
idades
# Out:
# [20, 39, 30, 27, 19]

# %%
itens = [20, 39, 18]

# %%
idades.append([27, 19])

# %%
idades
# Out:
# [20, 39, 30, 27, 19, [27, 19]]

# %%
for elemento in idades:
    print('Recebi o elemento', elemento)
# Out:
# Recebi o elemento 20
# Recebi o elemento 39
# Recebi o elemento 30
# Recebi o elemento 27
# Recebi o elemento 19
# Recebi o elemento [27, 19]

# %%
idades.remove([27, 19])

# %%
idades
# Out:
# [20, 39, 30, 27, 19]

# %%
# Adicionando vários elementos à uma lista de uma vez
idades.extend([27, 19])
idades
# Out:
# [20, 39, 30, 27, 19, 27, 19]

# %%
for idade in idades:
    print(idade + 1)
# Out:
# 21
# 40
# 31
# 28
# 20
# 28
# 20

# %%
idades_no_ano_que_vem = []
for idade in idades:
    idades_no_ano_que_vem.append(idade+1)

# %%
# List Comprehension
[(idade+1) for idade in idades]
# Out:
# [21, 40, 31, 28, 20, 28, 20]

# %%
idades_no_ano_que_vem = [(idade+1) for idade in idades]
idades_no_ano_que_vem
# Out:
# [21, 40, 31, 28, 20, 28, 20]

# %%
[(idade) for idade in idades if idade > 21]
# Out:
# [39, 30, 27, 27]

# %%
# Definindo uma função
def proximo_ano(idade):
    return idade+1

# %%
[proximo_ano(idade) for idade in idades if idade > 21]
# Out:
# [40, 31, 28, 28]

# %%
# Problemas com mutabilidade da lista
def faz_processamento_de_visualizacao(lista):
    print(len(lista))
    lista.append(13)

# %%
idades = [16, 21, 29, 56, 43]
faz_processamento_de_visualizacao(idades)
# Out:
# 5

# %%
def faz_processamento_de_visualizacao(lista=[]):
    print(len(lista))
    lista.append(13)

# %%
faz_processamento_de_visualizacao()
# Out:
# 0

# %%
faz_processamento_de_visualizacao()
# Out:
# 1

# %%
faz_processamento_de_visualizacao()
# Out:
# 2

# %%
def faz_processamento_de_visualizacao(lista=None):
    if lista == None:
        lista = list()
    print(len(lista))
    print(lista)
    lista.append(13)

# %%
faz_processamento_de_visualizacao()
# Out:
# 0
# []

# %%
faz_processamento_de_visualizacao()
# Out:
# 0
# []

# %%
class ContaCorrente:
    def __init__(self, codigo):
        self.codigo = codigo
        self.saldo = 0

    def deposita(self, valor):
        self.saldo += valor

    def __str__(self):
        return f'>>>>> Código {self.codigo} Saldo {self.saldo} <<<<<'

# %%
conta_do_bruno = ContaCorrente(15)

# %%
print(conta_do_bruno)
# Out:
# >>>>> Código 15 Saldo 0 <<<<<

# %%
conta_do_bruno.deposita(500)

# %%
print(conta_do_bruno)
# Out:
# >>>>> Código 15 Saldo 500 <<<<<

# %%
conta_da_julia = ContaCorrente(47685)

# %%
conta_da_julia.deposita(1000)

# %%
 print(conta_da_julia)
# Out:
# >>>>> Código 47685 Saldo 1000 <<<<<

# %%
contas = [conta_do_bruno, conta_da_julia]

# %%
print(contas)
# Out:
# [<__main__.ContaCorrente object at 0x7f16c2110cd0>, <__main__.ContaCorrente object at 0x7f16c211f050>]

# %%
for conta in contas:
    print(conta)
# Out:
# >>>>> Código 15 Saldo 500 <<<<<
# >>>>> Código 47685 Saldo 1000 <<<<<

# %%
contas.append(conta_do_bruno)

# %%
contas[2].deposita(300)

# %%
print(conta_do_bruno)
# Out:
# >>>>> Código 15 Saldo 800 <<<<<

# %%
contas[0].deposita(100)

# %%
print(conta_do_bruno)
# Out:
# >>>>> Código 15 Saldo 900 <<<<<

# %%
contas = [conta_do_bruno, conta_da_julia]

# %%
def deposita_para_todas(contas):
    for conta in contas:
        conta.deposita(100)

# %%
deposita_para_todas(contas)

# %%
print(contas[0], contas[1])
# Out:
# >>>>> Código 15 Saldo 1000 <<<<< >>>>> Código 47685 Saldo 1100 <<<<<

# %%
contas.insert(0, 76)

# %%
print(contas[0], contas[1], contas[2])
# Out:
# 76 >>>>> Código 15 Saldo 1000 <<<<< >>>>> Código 47685 Saldo 1100 <<<<<

# %%
# Tuplas
bruno = ('Bruno', 27, 1994)
julia = ('Julia', 24, 1996)

# %%
conta_do_bruno = (15, 1000)
conta_do_bruno[1]
# Out:
# 1000

# %%
def deposita(conta): # variação "funcional" separando o comportamento dos dados
    novo_saldo = conta[1] + 100
    codigo = conta[0]
    return (codigo, novo_saldo)

# %%
conta_do_bruno = deposita(conta_do_bruno)
conta_do_bruno
# Out:
# (15, 1100)

# %%
# Lista de tuplas
usuarios = [bruno, julia]
usuarios
# Out:
# [('Bruno', 27, 1994), ('Julia', 24, 1996)]

# %%
usuarios.append(('Frodo', 127, 938))

# %%
usuarios
# Out:
# [('Bruno', 27, 1994), ('Julia', 24, 1996), ('Frodo', 127, 938)]

# %%
usuarios[0]
# Out:
# ('Bruno', 27, 1994)

# %%
conta_do_bruno = ContaCorrente(15)
conta_do_bruno.deposita(500)
conta_da_julia = ContaCorrente(234876)
conta_da_julia.deposita(1000)

# %%
contas = (conta_do_bruno, conta_da_julia)
contas
# Out:
# (<__main__.ContaCorrente at 0x7f16c2137e50>,
#  <__main__.ContaCorrente at 0x7f16c2137e90>)

# %%
for conta in contas:
    print(conta)
# Out:
# >>>>> Código 15 Saldo 500 <<<<<
# >>>>> Código 234876 Saldo 1000 <<<<<

# %%
contas[0].deposita(300)

# %%
for conta in contas:
    print(conta)
# Out:
# >>>>> Código 15 Saldo 800 <<<<<
# >>>>> Código 234876 Saldo 1000 <<<<<

# %% [markdown]
# # Herança e Polimorfismo

# %%
class Conta:
    def __init__(self, codigo):
        self._codigo = codigo
        self._saldo = 0
    
    def deposita(self, valor):
        self._saldo += valor

    def __str__(self):
        return f'[>> Código {self._codigo} Saldo {self._saldo} <<]'

# %%
class ContaCorrente(Conta):
    
    def passa_o_mes(self):
        self._saldo -= 2

class ContaPoupanca(Conta):
    
    def passa_o_mes(self):    
        self._saldo *= 1.01
        self._saldo -= 3

# %%
conta88 = Conta(88)
print(conta88)
# Out:
# [>> Código 88 Saldo 0 <<]

# %%
conta16 = ContaCorrente(16)
conta16.deposita(1000)
conta16.passa_o_mes()
print(conta16)
# Out:
# [>> Código 16 Saldo 998 <<]

# %%
conta17 = ContaPoupanca(17)
conta17.deposita(1000)
conta17.passa_o_mes()
print(conta17)
# Out:
# [>> Código 17 Saldo 1007.0 <<]

# %%
conta16 = ContaCorrente(16)
conta17 = ContaPoupanca(17)
contas = [conta16, conta17]

# %%
for conta in contas:
    conta.passa_o_mes()
    print(conta)
# Out:
# [>> Código 16 Saldo -2 <<]
# [>> Código 17 Saldo -3.0 <<]

# %% [markdown]
# # Arrays

# %%
import array as arr

# %%
# Instanciando um array
arr.array('d', [1, 3.5])
# Out:
# array('d', [1.0, 3.5])

# %%
import numpy as np

# %%
np.array([1, 3.5])
# Out:
# array([1. , 3.5])

# %%
np.array([1, 3.5]) + 3
# Out:
# array([4. , 6.5])

# %% [markdown]
# # Método abstrato

# %%
from abc import ABCMeta, abstractmethod

class Conta(metaclass=ABCMeta):
    def __init__(self, codigo):
        self._codigo = codigo
        self._saldo = 0
    
    def deposita(self, valor):
        self._saldo += valor

    @abstractmethod
    def passa_o_mes(self):
        pass

    def __str__(self):
        return f'[>> Código {self._codigo} Saldo {self._saldo} <<]'


class ContaCorrente(Conta):
    
    def passa_o_mes(self):
        self._saldo -= 2


class ContaPoupanca(Conta):
    
    def passa_o_mes(self):    
        self._saldo *= 1.01
        self._saldo -= 3


class ContaInvestimento(Conta):
    pass

# %%
class ContaSalario:
    def __init__(self, codigo):
        self.codigo = codigo
        self.saldo = 0
        
        
    def deposita(self, valor):
        self.saldo += valor

    
    def __str__(self):
        return f'[>>> Código {self.codigo}, Saldo {self.saldo} <<<]'

# %%
conta1 = ContaSalario(37)
print(conta1)
# Out:
# [>>> Código 37, Saldo 0 <<<]

# %%
conta2 = ContaSalario(37)
print(conta2)
# Out:
# [>>> Código 37, Saldo 0 <<<]

# %% [markdown]
# > Se testar a igualdade entre as duas contas acima, o resultado retornado será False, porque a igualdade '==' só retorna True se as duas referências forem iguais.

# %%
# Testando a igualdade
conta1 == conta2
# Out:
# False

# %%
# Definindo a condição de igualdades
class ContaSalario:
    def __init__(self, codigo):
        self.codigo = codigo
        self.saldo = 0
        
        
    def deposita(self, valor):
        self.saldo += valor


    # condição de igualdade
    def __eq__(self, outro):
        if type(outro) != ContaSalario:
            return False

        if self.codigo == outro.codigo:
            return True
        else:
            return False

    
    def __str__(self):
        return f'[>>> Código {self.codigo}, Saldo {self.saldo} <<<]'

# %%
conta1 = ContaSalario(37)
conta2 = ContaSalario(37)

# %%
# Testando a condição de igualdade
conta1 == conta2
# Out:
# True

# %%
contas = [conta1]

# %%
conta2 in contas
# Out:
# True

# %%
conta1 in contas
# Out:
# True

# %%
conta3 = ContaCorrente(37)

# %%
conta1 == conta3
# Out:
# False

# %%
class ContaMultiploSalario(ContaSalario):
    pass

# %%
conta4 = ContaMultiploSalario(37)

# %%
conta1 == conta4
# Out:
# True

# %%
isinstance(conta3, ContaSalario)
# Out:
# False

# %% [markdown]
# # <font color='orange'> Enumerated, range e desempacotamento de tuplas</font>

# %%
idades = [15, 87, 32, 65, 56, 32, 49, 37]

# %%
for idade in idades:
    print(idade)
# Out:
# 15
# 87
# 32
# 65
# 56
# 32
# 49
# 37

# %%
for i in range(len(idades)):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
for i in range(len(idades)):
    print(i, idades[i])
# Out:
# 0 15
# 1 87
# 2 32
# 3 65
# 4 56
# 5 32
# 6 49
# 7 37

# %%
enumerate(idades) # lazy...

# %%
# forçando a geração de valores
list(enumerate(idades))
# Out:
# [(0, 15), (1, 87), (2, 32), (3, 65), (4, 56), (5, 32), (6, 49), (7, 37)]

# %%
for valor in enumerate(idades):
    print(valor)
# Out:
# (0, 15)
# (1, 87)
# (2, 32)
# (3, 65)
# (4, 56)
# (5, 32)
# (6, 49)
# (7, 37)

# %%
usuarios = [
    ('Bruno', 27, 1994),
    ('Júlia', 24, 1996),
    ('Tony', 34, 1980)
]

# %%
for nome, idade, nascimento in usuarios:
    print(nome)
# Out:
# Bruno
# Júlia
# Tony

# %%
for nome, _, _ in usuarios:
    print(nome)
# Out:
# Bruno
# Júlia
# Tony

# %%
list(enumerate(usuarios))
# Out:
# [(0, ('Bruno', 27, 1994)), (1, ('Júlia', 24, 1996)), (2, ('Tony', 34, 1980))]

# %%
list(range(len(idades)))
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]

# %%
sorted(idades)
# Out:
# [15, 32, 32, 37, 49, 56, 65, 87]

# %%
sorted(idades, reverse=True)
# Out:
# [87, 65, 56, 49, 37, 32, 32, 15]

# %%
list(reversed(idades))
# Out:
# [37, 49, 32, 56, 65, 32, 87, 15]

# %%
list(reversed(sorted(idades)))
# Out:
# [87, 65, 56, 49, 37, 32, 32, 15]

# %% [markdown]
# # <font color='orange'>Ordenação de objetos sem ordem natural</font>

# %%
nomes = ['Bruno', 'Julia', 'Frodo']
sorted(nomes)
# Out:
# ['Bruno', 'Frodo', 'Julia']

# %%
nomes = ['bruno', 'Julia', 'Frodo']
sorted(nomes)
# Out:
# ['Frodo', 'Julia', 'bruno']

# %%
class ContaSalario:
    def __init__(self, codigo):
        self._codigo = codigo
        self._saldo = 0


    # condição de igualdade
    def __eq__(self, outro):
        if type(outro) != ContaSalario:
            return False

        return self._codigo == outro._codigo and self._saldo == outro._saldo


    def deposita(self, valor):
        self._saldo += valor
        
    
    def __str__(self):
        return f'[>>> Código {self._codigo}, Saldo {self._saldo} <<<]'

# %%
conta_bruno = ContaSalario(17)
conta_bruno.deposita(500)

conta_julia = ContaSalario(3)
conta_julia.deposita(1000)

conta_frodo = ContaSalario(133)
conta_frodo.deposita(510)

# %%
contas = [conta_bruno, conta_julia, conta_frodo]

# %%
for conta in contas:
    print(conta)
# Out:
# [>>> Código 17, Saldo 500 <<<]
# [>>> Código 3, Saldo 1000 <<<]
# [>>> Código 133, Saldo 510 <<<]

# %%
# Ordenaando as contas
def extrai_saldo(conta):
    return conta._saldo

for conta in sorted(contas, key=extrai_saldo):
    print(conta)
# Out:
# [>>> Código 17, Saldo 500 <<<]
# [>>> Código 133, Saldo 510 <<<]
# [>>> Código 3, Saldo 1000 <<<]

# %%
from operator import attrgetter

for conta in sorted(contas, key=attrgetter('_saldo')):
    print(conta)
# Out:
# [>>> Código 17, Saldo 500 <<<]
# [>>> Código 133, Saldo 510 <<<]
# [>>> Código 3, Saldo 1000 <<<]

# %% [markdown]
# # <font color='orange'>Implementando o \_\_lt__</font>

# %%
class ContaSalario:
    def __init__(self, codigo):
        self._codigo = codigo
        self._saldo = 0


    # condição de igualdade
    def __eq__(self, outro):
        if type(outro) != ContaSalario:
            return False

        return self._codigo == outro._codigo and self._saldo == outro._saldo


    def deposita(self, valor):
        self._saldo += valor


    def __lt__(self, outro):
        return self._saldo < outro._saldo
        
    
    def __str__(self):
        return f'[>>> Código {self._codigo}, Saldo {self._saldo} <<<]'

# %%
conta_bruno = ContaSalario(17)
conta_bruno.deposita(500)

conta_julia = ContaSalario(3)
conta_julia.deposita(1000)

conta_frodo = ContaSalario(133)
conta_frodo.deposita(510)

contas = [conta_bruno, conta_julia, conta_frodo]

# %%
conta_bruno < conta_julia
# Out:
# True

# %%
conta_bruno > conta_julia
# Out:
# False

# %%
for conta in sorted(contas):
    print(conta)
# Out:
# [>>> Código 17, Saldo 500 <<<]
# [>>> Código 133, Saldo 510 <<<]
# [>>> Código 3, Saldo 1000 <<<]

# %%
for conta in sorted(contas, reverse=True):
    print(conta)
# Out:
# [>>> Código 3, Saldo 1000 <<<]
# [>>> Código 133, Saldo 510 <<<]
# [>>> Código 17, Saldo 500 <<<]

# %% [markdown]
# # <font color='orange'>Ordenação completa e functools</font>

# %%
conta_bruno = ContaSalario(1700)
conta_bruno.deposita(500)

conta_julia = ContaSalario(3)
conta_julia.deposita(1000)

conta_frodo = ContaSalario(133)
conta_frodo.deposita(500)

contas = [conta_bruno, conta_julia, conta_frodo]

# %%
for conta in sorted(contas, key=attrgetter('_saldo', '_codigo')):
    print(conta)
# Out:
# [>>> Código 133, Saldo 500 <<<]
# [>>> Código 1700, Saldo 500 <<<]
# [>>> Código 3, Saldo 1000 <<<]

# %%
conta_bruno = ContaSalario(1700)
conta_bruno.deposita(500)

conta_julia = ContaSalario(3)
conta_julia.deposita(500)

conta_frodo = ContaSalario(133)
conta_frodo.deposita(500)

contas = [conta_bruno, conta_julia, conta_frodo]

# %%
for conta in sorted(contas, key=attrgetter('_saldo', '_codigo')):
    print(conta)
# Out:
# [>>> Código 3, Saldo 500 <<<]
# [>>> Código 133, Saldo 500 <<<]
# [>>> Código 1700, Saldo 500 <<<]

# %%
class ContaSalario:
    def __init__(self, codigo):
        self._codigo = codigo
        self._saldo = 0


    # condição de igualdade
    def __eq__(self, outro):
        if type(outro) != ContaSalario:
            return False

        return self._codigo == outro._codigo and self._saldo == outro._saldo


    def deposita(self, valor):
        self._saldo += valor


    def __lt__(self, outro):
        if self._saldo != outro._saldo:
            return self._saldo < outro._saldo
        
        return self._codigo < outro._codigo

    
    def __str__(self):
        return f'[>>> Código {self._codigo}, Saldo {self._saldo} <<<]'

# %%
conta_bruno = ContaSalario(1700)
conta_bruno.deposita(500)

conta_julia = ContaSalario(3)
conta_julia.deposita(500)

conta_frodo = ContaSalario(133)
conta_frodo.deposita(500)

contas = [conta_bruno, conta_julia, conta_frodo]

# %%
for conta in sorted(contas):
    print(conta)
# Out:
# [>>> Código 3, Saldo 500 <<<]
# [>>> Código 133, Saldo 500 <<<]
# [>>> Código 1700, Saldo 500 <<<]

# %%
from functools import total_ordering

@total_ordering
class ContaSalario:
    def __init__(self, codigo):
        self._codigo = codigo
        self._saldo = 0


    # condição de igualdade
    def __eq__(self, outro):
        if type(outro) != ContaSalario:
            return False

        return self._codigo == outro._codigo and self._saldo == outro._saldo


    def deposita(self, valor):
        self._saldo += valor


    def __lt__(self, outro):
        if self._saldo != outro._saldo:
            return self._saldo < outro._saldo
        
        return self._codigo < outro._codigo

    
    def __str__(self):
        return f'[>>> Código {self._codigo}, Saldo {self._saldo} <<<]'

# %%
conta_bruno = ContaSalario(1700)
conta_bruno.deposita(500)

conta_julia = ContaSalario(3)
conta_julia.deposita(500)

conta_frodo = ContaSalario(133)
conta_frodo.deposita(1000)

contas = [conta_bruno, conta_julia, conta_frodo]

# %%
conta_bruno <= conta_julia
# Out:
# False

# %%
conta_bruno <= conta_frodo
# Out:
# True

# %%
conta_bruno == conta_julia
# Out:
# False

# %%
conta_bruno == conta_bruno
# Out:
# True

# %%
conta_bruno <= conta_bruno
# Out:
# True
